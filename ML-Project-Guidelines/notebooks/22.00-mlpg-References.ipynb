# %% [markdown]
# <!--BOOK_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="figures/MLPG-Book-Cover-Small.png"><br>
#
# This notebook contains an excerpt from the **`Machine Learning Project Guidelines - For Beginners`** book written by *Balasubramanian Chandran*; the content is available [on GitHub](https://github.com/BalaChandranGH/Books/ML-Project-Guidelines).

# %% [markdown]
# <br>
# <!--NAVIGATION-->
#
# <[ [Case Study 3: Normalize and sort dates using Regular Expressions](21.03-mlpg-CS3-Normalize-and-sort-dates-using-Regular-Expressions.ipynb) | [Contents and Acronyms](00.00-mlpg-Contents-and-Acronyms.ipynb) ]>

# %% [markdown]
# # 22. References

# %% [markdown]
# 1. [1.] Introduction to Machine Learning<br>
#    (https://www.analyticsvidhya.com/machine-learning/)<br>
#    (https://www.analyticsvidhya.com/blog/2017/09/common-machine-learning-algorithms/)
#
# 2. [1.4.] Types of Machine Learning<br>
#    https://machinelearningmastery.com/what-is-semi-supervised-learning/
#
# 3. [1.6.] Difference between ML Algorithms and ML Models<br>
#    (https://machinelearningmastery.com/difference-between-algorithm-and-model-in-machine-learning/)
#
# 4. [2.] Grouping of ML Algorithms<br>
#    (https://machinelearningmastery.com/a-tour-of-machine-learning-algorithms/)<br>
#    (https://www.analyticsvidhya.com/blog/2017/09/common-machine-learning-algorithms/)
#
# 5. [3.] Pros & Cons of ML algorithms<br>
#    (https://www.coursera.org/)<br>
#
# 6. [3.1.] Linear Regression - Ordinary Least Squares<br>
#    (https://www.quora.com/)<br>
#
# 7. [3.2.] Linear Regression - Ridge Regression<br>
#    (https://www.analyticsvidhya.com/blog/2016/01/ridge-lasso-regression-python-complete-tutorial/)<br>
#    (https://www.quora.com/)
#
# 8. [3.3.] Linear Regression - Lasso Regression<br>
#    (https://www.analyticsvidhya.com/blog/2016/01/ridge-lasso-regression-python-complete-tutorial/)
#
# 9. [3.4.] Linear Regression - Polynomial Regression<br>
#    (https://towardsdatascience.com/introduction-to-linear-regression-and-polynomial-regression-f8adc96f31cb)
#
# 10. [3.5.] Linear Regression - Logistic Regression<br>
#     (https://machinelearning-blog.com/2018/04/23/logistic-regression-101/)<br>
#     (https://www.edvancer.in/logistic-regression-vs-decision-trees-vs-svm-part2/)
#
# 11. [3.6.] k-Nearest Neighbor<br>
#     (https://www.fromthegenesis.com/pros-and-cons-of-k-nearest-neighbors/)<br>
#     (http://theprofessionalspoint.blogspot.com/2019/02/advantages-and-disadvantages-of-knn.html)
#
# 12. [3.7.] Support Vector Machines<br>
#     (https://www.coursera.org/)
#
# 13. [3.8.] Decision Trees<br>
#     (https://github.com/pb111/Decision-Tree-Classification-Project)
#
# 14. [3.9.] Naïve Bayes<br>
#     (https://github.com/pb111/Naive-Bayes-Classification-Project)
#
# 15. [3.10.] Random Forest<br>
#     (https://github.com/pb111/Random-Forest-Classifier-Project)
#
# 16. [3.11.] Extreme Gradient Boosting (XGBoost)<br>
#     (https://github.com/pb111/XGBoost-Classification-Project)
#
# 17. [3.12.] K-Means Clustering (K-Means)<br>
#     (https://github.com/pb111/K-Means-Clustering-Project)
#
# 18. [8.1.3.] Types of Variables<br>
#     (https://www.formpl.us/blog/nominal-ordinal-interval-ratio-variable-example)
#
# 19. [10.2.2.] Feature Selection<br>
#     (https://machinelearningmastery.com/feature-selection-with-real-and-categorical-data/)
#     (https://machinelearningmastery.com/calculate-feature-importance-with-python/)
#
# 20. [10.2.3.] Feature Engineering<br>
#     (https://www.kaggle.com/learn/feature-engineering)
#
# 21. [13.1.] Hyperparameters optimization<br>
#     (https://machinelearningmastery.com/hyperparameter-optimization-with-random-search-and-grid-search/)
#
# 22. [4-17.] DSPM Methodology - A Guideline for Beginners, 2021 [Balasubramanian Chandran]
#
# 23. [18.] Other Considerations<br>
#     (https://www.coursera.org/)<br>
#     (https://cognitiveclass.ai/)<br>
#     (https://github.com/)<br>
#     (https://numpy.org/)<br>
#     (https://pandas.pydata.org/)<br>
#     (https://scipy.org/)<br>
#     (https://www.statsmodels.org/)<br>
#     (https://matplotlib.org/)<br>
#     (https://seaborn.pydata.org/)<br>
#     (https://plotly.com/)<br>
#     (https://scikit-learn.org/)<br>
#     (https://www.kaggle.com/)<br>
#     (https://www.kdnuggets.com/)<br>
#     (https://pypi.org/project/folium/0.1.5/)<br>
#     (https://pypi.org/project/python-dateutil/)<br>
#     (https://pytorch.org/)<br>
#     (https://opencv.org/)<br>
#     (https://www.tensorflow.org/)<br>
#     (https://keras.io/)<br>
#     (https://stackoverflow.com/)<br>
#     (https://www.pinterest.com/)<br>
#     (https://xgboost.readthedocs.io/en/latest/)<br>
#     (https://gradio.app/)<br>
#     (https://beautiful-soup-4.readthedocs.io/)<br>
#     (https://en.wikipedia.org/)<br>
#     (https://machinelearningmastery.com/)<br>
#     (https://www.analyticsvidhya.com/)<br>
#     (https://towardsdatascience.com/)<br>
#     (https://medium.com/)<br>
#     (https://www.youtube.com/)<br>
#     (https://www.quora.com/)<br>
#     (https://machinelearningmastery.com/tune-xgboost-performance-with-learning-curves/)<br>
#     (https://machinelearningmastery.com/sensitivity-analysis-of-dataset-size-vs-model-performance/)<br>
#     (https://machinelearningmastery.com/no-free-lunch-theorem-for-machine-learning/)<br>
#     (https://machinelearningmastery.com/local-optimization-versus-global-optimization/)<br>
#     (https://machinelearningmastery.com/machine-learning-modeling-pipelines/)<br>
#     (https://machinelearningmastery.com/multinomial-logistic-regression-with-python/)<br>
#     (https://machinelearningmastery.com/why-use-ensemble-learning/)<br>
#     (https://machinelearningmastery.com/how-ensemble-learning-works/)<br>
#     (https://machinelearningmastery.com/overfitting-machine-learning-models/)<br>
#     (https://machinelearningmastery.com/pycaret-for-machine-learning/)<br>
#     (https://machinelearningmastery.com/robust-regression-for-machine-learning-in-python/)<br>
#     (https://machinelearningmastery.com/linear-discriminant-analysis-with-python/)<br>
#     (https://machinelearningmastery.com/radius-neighbors-classifier-algorithm-with-python/)<br>
#     (https://machinelearningmastery.com/gaussian-processes-for-classification-with-python/)<br>
#     (https://machinelearningmastery.com/clustering-algorithms-with-python/)<br>
#     (https://machinelearningmastery.com/recommender-systems-resources/)<br>
#     (https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/)<br>
#     (https://machinelearningmastery.com/model-based-outlier-detection-and-removal-in-python/)<br>
#     (https://machinelearningmastery.com/overfitting-and-underfitting-with-machine-learning-algorithms/)<br>
#     (https://machinelearningmastery.com/essence-of-boosting-ensembles-for-machine-learning/)<br>
#     (https://machinelearningmastery.com/bagging-ensemble-with-python/)<br>
#     (https://machinelearningmastery.com/bagging-and-random-forest-for-imbalanced-classification/)<br>
#     (https://www.kdnuggets.com/2020/05/guide-choose-right-machine-learning-algorithm.html)<br>
#     (https://www.kdnuggets.com/2021/03/top-10-python-libraries-2021.html)<br>
#     (https://www.analyticsvidhya.com/blog/2018/04/fundamentals-deep-learning-regularization-techniques/)<br>
#     (https://www.analyticsvidhya.com/blog/2020/02/cnn-vs-rnn-vs-mlp-analyzing-3-types-of-neural-networks-in-deep-learning/)<br>
#     (https://www.analyticsvidhya.com/blog/2021/04/create-interface-for-your-machine-learning-models-using-gradio-python-library/)<br>
#     (https://www.analyticsvidhya.com/blog/2017/07/web-scraping-in-python-using-scrapy/)<br>
#     (https://www.analyticsvidhya.com/blog/2018/06/comprehensive-guide-recommendation-engine-python/)<br>
#     (https://discuss.analyticsvidhya.com/t/which-one-to-use-randomforest-vs-svm-vs-knn/2897)<br>
#     (https://www.analyticsvidhya.com/blog/2021/07/recommendation-system-understanding-the-basic-concepts/)<br>
#     (https://towardsdatascience.com/a-complete-guide-to-natural-language-processing-nlp-c91f1cfd3b0c)<br>
#     (https://pub.towardsai.net/the-last-20-python-packages-you-will-ever-need-a4bc0a0d1214)<br>
#     (https://datascience.stackexchange.com/questions/6838/when-to-use-random-forest-over-svm-and-vice-versa)<br>
#     (https://www.datacamp.com/community/tutorials/xgboost-in-python)<br>
#     (https://citoolkit.com/articles/histograms-and-boxplots/)<br>
#     (https://docs.microsoft.com/en-us/azure/machine-learning/how-to-select-algorithms)<br>
#     (https://www.zyte.com/learn/what-is-web-scraping/)<br>
#     (https://www.quora.com/What-are-kernels-in-machine-learning-and-SVM-and-why-do-we-need-them)<br>
#     (https://www.anodot.com/blog/what-is-anomaly-detection/)<br>
#     (https://cdn.oreillystatic.com/en/assets/1/event/105/Overcoming%20the%20Barriers%20to%20Production-Ready%20Machine-Learning%20Workflows%20Presentation%201.pdf)<br>
#     (https://faculty.marshall.usc.edu/gareth-james/index.html)<br>
#     (https://blogs.sas.com/content/subconsciousmusings/2020/12/09/machine-learning-algorithm-use/)<br>
#     (https://bigdatapath.wordpress.com/2019/11/13/understanding-the-7-vs-of-big-data/)<br>
#     (https://www.researchgate.net/figure/The-7Vs-of-Big-Data-Volume-Velocity-Variety-Variability-Veracity-Value-and_fig1_341622174)<br>
#
# 24. [19.] Text Analytics: An Introduction<br>
#     (https://www.coursera.org/) - Applied Text Mining in Python course
#
# 20.	Social Network Analysis: An Introduction<br>
#     (https://cognitiveclass.ai/) - Applied Social Network Analysis in Python course

# %% [markdown]
# <!--NAVIGATION-->
# <br>
#
# <[ [Case Study 3: Normalize and sort dates using Regular Expressions](21.03-mlpg-CS3-Normalize-and-sort-dates-using-Regular-Expressions.ipynb) | [Contents and Acronyms](00.00-mlpg-Contents-and-Acronyms.ipynb) ]>
